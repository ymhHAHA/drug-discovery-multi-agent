# %% [markdown]
# # 药物靶点发现多智能体系统 - Colab Demo
#
# 这是一个基于LangGraph的药物靶点发现多智能体系统的演示。

# %%
# 安装依赖
# !pip install -q langgraph langchain-core dashscope

# %%
# 克隆项目（如果需要）
# !git clone https://github.com/yourusername/drug-discovery-multiagent.git
# %cd drug-discovery-multiagent

# %%
# 设置API Key
import os
os.environ["DASHSCOPE_API_KEY"] = "your-api-key-here"  # 替换为你的API Key

# %%
# 运行分析
from main import run_analysis

# 分析肺癌
result = run_analysis("肺癌")

# %%
# 查看生成的文件
# !ls *.md
